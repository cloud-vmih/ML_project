# %%
import pandas as pd
import numpy as np

data = pd.read_csv(r'D:\MachineLearning\Project\data\raw\all_movies_data.csv')
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62650 entries, 0 to 62649
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Title                  62650 non-null  object
#  1   Year                   62650 non-null  int64
#  2   Duration               60585 non-null  object
#  3   MPA                    40818 non-null  object
#  4   Rating                 58610 non-null  float64
#  5   Votes                  58610 non-null  object
#  6   méta_score             15526 non-null  float64
#  7   description            60318 non-null  object
#  8   Movie Link             62650 non-null  object
#  9   writers                62650 non-null  object
#  10  directors              62650 non-null  object
#  11  stars                  62307 non-null  object
#  12  budget                 15293 non-null  object
#  13  opening_weekend_Gross  16837 non-null  object
# ...
